# %%
#IMPORTING THE FILE

import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
#TEXT

text_input = widgets.Text(
    description='Text:',
    placeholder='Enter something'
)

# %%
#DROPDOWN

dropdown = widgets.Dropdown(
    options=['Option 1', 'Option 2', 'Option 3'],
    description='Dropdown:'
)

# %%
#SLIDER

slider = widgets.IntSlider(
    value=50,
    min=0,
    max=100,
    step=1,
    description='Slider:'
)
output = widgets.Output()

# %%
#PRINTING THE OUTPUT

def on_button_click(b):
    with output:
        clear_output()
        print(f"Text Box: {text_input.value}")
        print(f"Dropdown Selected: {dropdown.value}")
        print(f"Slider Value: {slider.value}")

button = widgets.Button(
    description='Submit'
)
button.on_click(on_button_click)
display(text_input, dropdown, slider, button, output)
# Out:
# Text(value='', description='Text:', placeholder='Enter something')
# Dropdown(description='Dropdown:', options=('Option 1', 'Option 2', 'Option 3'), value='Option 1')
# IntSlider(value=50, description='Slider:')
# Button(description='Submit', style=ButtonStyle())
# Output()
